# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import shapiro, kstest

pd.set_option('display.max_columns',None)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("world_data_full_apply_nulos.csv",index_col=0)

# %% [markdown]
# Calcula las siguientes estadísticas descriptivas para las variables numéricas:
#
# Media
#
# Mediana
#
# Desviación estándar
#
# Mínimo
#
# Máximo

# %%
df.head(2)
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# 1          4.536  119.05         1.4           ALL            1.62
#
#    forested_area  gasoline_price           gdp  \
# 0            2.1            0.70  1.910135e+10
# 1           28.1            1.36  1.527808e+10
#
#    gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 0                               104.0                                  9.7
# ...

# %%
df["density"].mean()
# Out:
# 134.50453333333334

# %%
df["density"].median()
# Out:
# 83.0

# %%
df["density"].std()
# Out:
# 157.3067742999071

# %%
df["density"].max()
# Out:
# 847.0

# %%
df["density"].min()
# Out:
# 1.265

# %%
df.describe().T
# Out:
#                                       count          mean           std  \
# density                               195.0  1.345045e+02  1.573068e+02
# agricultural_land                     188.0  3.911755e+01  2.178305e+01
# land_area                             165.0  2.552127e+02  2.583850e+02
# armed_forces_size                     166.0  1.037831e+02  1.671580e+02
# birth_rate                            189.0  2.021497e+01  9.945774e+00
# calling_code                          194.0  3.605464e+02  3.232364e+02
# co2-emissions                         183.0  1.259155e+02  1.817949e+02
# cpi                                   175.0  1.441936e+02  5.478400e+01
# cpi_change                            179.0  6.722346e+00  2.445041e+01
# fertility_rate                        188.0  2.698138e+00  1.282267e+00
# forested_area                         188.0  3.201543e+01  2.379133e+01
# gasoline_price                        175.0  1.002457e+00  3.688585e-01
# ...

# %% [markdown]
# Identifica el país con la mayor densidad de población y el país con la menor población en el conjunto de datos.

# %%
#df["country"].max(df["density"])
#df["density"].groupby(df["country"]).count()
df[["density","country"]].max()
# Out:
# density       847.0
# country    Zimbabwe
# dtype: object

# %%
df[["density","country"]].min()
# Out:
# density          1.265
# country    Afghanistan
# dtype: object

# %% [markdown]
# Calcula la tasa promedio de natalidad (birth_rate) para todos los países en el conjunto de datos.

# %%
df["birth_rate"].groupby(df["country"]).mean()
# Out:
# country
# Afghanistan    32.49
# Albania        11.78
# Algeria        24.28
# Andorra         7.20
# Angola         40.73
#                ...
# Venezuela      17.88
# Vietnam        16.75
# Yemen          30.45
# Zambia         36.19
# Zimbabwe       30.68
# Name: birth_rate, Length: 195, dtype: float64

# %%
ejemplo = df["birth_rate"].groupby(df["country"]).mean().reset_index()

# %%
ejemplo
# Out:
#          country  birth_rate
# 0    Afghanistan       32.49
# 1        Albania       11.78
# 2        Algeria       24.28
# 3        Andorra        7.20
# 4         Angola       40.73
# ..           ...         ...
# 190    Venezuela       17.88
# 191      Vietnam       16.75
# 192        Yemen       30.45
# 193       Zambia       36.19
# 194     Zimbabwe       30.68
#
# [195 rows x 2 columns]

# %% [markdown]
# Realiza un análisis de la mortalidad infantil (infant_mortality) y clasifica los países en tres categorías: baja, moderada y alta mortalidad infantil.

# %%
analisismortin = df["infant_mortality"].groupby(df["country"]).mean().reset_index()

# %%
analisismortin
# Out:
#          country  infant_mortality
# 0    Afghanistan              47.9
# 1        Albania               7.8
# 2        Algeria              20.1
# 3        Andorra               2.7
# 4         Angola              51.6
# ..           ...               ...
# 190    Venezuela              21.4
# 191      Vietnam              16.5
# 192        Yemen              42.9
# 193       Zambia              40.4
# 194     Zimbabwe              33.9
#
# [195 rows x 2 columns]

# %%
Q1 = np.nanpercentile(df["infant_mortality"],25)
Q1
# Out:
# 6.0

# %%
Q2=df["infant_mortality"].median()
Q2
# Out:
# 14.0

# %%
Q3 = np.nanpercentile(df["infant_mortality"],75)
Q3
# Out:
# 32.7

# %%
def rangos(valor):
    if valor<Q1:
        return "bajo"
    elif Q1<=valor<=Q2:
        return "medio"
    else:
        Q2<=valor<=Q3
        return "alto"

# %%
rangos(7)
# Out:
# 'medio'

# %%
#aquí habría que hacer un apply y hacer una columna con esto. para después poder comparar

# %%
df.head()
# Out:
#        country  density abbreviation  agricultural_land  land_area  \
# 0  Afghanistan     60.0           AF               58.1    652.230
# 1      Albania    105.0           AL               43.1     28.748
# 2      Algeria     18.0           DZ               17.4        NaN
# 3      Andorra    164.0           AD               40.0    468.000
# 4       Angola     26.0           AO               47.5        NaN
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0          8.672  149.90         2.3           AFN            4.47
# ...

# %%
sns.barplot(x="infant_mortality", data=analisismortin, hue="country")
# Out:
# <Axes: xlabel='infant_mortality'>

# %%
IQR = Q3-Q1
IQR
# Out:
# 26.700000000000003

# %%
distancia_bigote=IQR*1.5

# %%
bigote_derecho=Q3+distancia_bigote
bigote_derecho
# Out:
# 72.75

# %%
bigote_izquierdo=Q1-distancia_bigote
bigote_izquierdo
# Out:
# -34.050000000000004

# %%
sns.barplot(x="infant_mortality", data=analisismortin, hue="country")
#sns.boxplot(x="infant_mortality", data=analisismortin)
# Out:
# <Axes: xlabel='infant_mortality', ylabel='country'>
